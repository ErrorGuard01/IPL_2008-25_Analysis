# %%
import numpy as np
import pandas as pd

# %%
ipl=pd.read_csv(r"C:\Users\Vijay\Data Analytics\IPL_2008-25_Analysis\IPL.csv")
# Out:
# C:\Users\Vijay\AppData\Local\Temp\ipykernel_20332\884757736.py:1: DtypeWarning: Columns (28,29,30,31,43,46,47,48,51) have mixed types. Specify dtype option on import or set low_memory=False.
#   ipl=pd.read_csv(r"C:\Users\Vijay\Data Analytics\IPL_2008-25_Analysis\IPL.csv")

# %%
ipl=pd.read_csv(r"C:\Users\Vijay\Data Analytics\IPL_2008-25_Analysis\IPL.csv", low_memory=False)

# %%
#shape of dataframe
print("shape of dataframe\n")
print(ipl.shape)
#columns
print("columns\n")
print(ipl.columns)
#total null values
print("total null values\n")
print(ipl.isnull().sum())
#total no null values
print("total no null values\n")
print(ipl.count())
#top 10 rows
print("top 10 rows\n")
print(ipl.head(10))
#bottom 10 rows
print("bottom 10 rows\n")
print(ipl.tail(10))
# Out:
# shape of dataframe
#
# (278205, 64)
# columns
#
# Index(['Unnamed: 0', 'match_id', 'date', 'match_type', 'event_name', 'innings',
#        'batting_team', 'bowling_team', 'over', 'ball', 'ball_no', 'batter',
#        'bat_pos', 'runs_batter', 'balls_faced', 'bowler', 'valid_ball',
#        'runs_extras', 'runs_total', 'runs_bowler', 'runs_not_boundary',
#        'extra_type', 'non_striker', 'non_striker_pos', 'wicket_kind',
#        'player_out', 'fielders', 'runs_target', 'review_batter',
#        'team_reviewed', 'review_decision', 'umpire', 'umpires_call',
#        'player_of_match', 'match_won_by', 'win_outcome', 'toss_winner',
#        'toss_decision', 'venue', 'city', 'day', 'month', 'year', 'season',
#        'gender', 'team_type', 'superover_winner', 'result_type', 'method',
#        'balls_per_over', 'overs', 'event_match_no', 'stage', 'match_number',
#        'team_runs', 'team_balls', 'team_wicket', 'new_batter', 'batter_runs',
#        'batter_balls', 'bowler_wicket', 'batting_partners', 'next_batter',
#        'striker_out'],
#       dtype='object')
# total null values
#
# Unnamed: 0               0
# match_id                 0
# date                     0
# match_type               0
# event_name               0
#                      ...
# batter_balls             0
# bowler_wicket            0
# batting_partners         0
# next_batter         264884
# striker_out              0
# Length: 64, dtype: int64
# total no null values
#
# Unnamed: 0          278205
# match_id            278205
# date                278205
# match_type          278205
# event_name          278205
#                      ...
# batter_balls        278205
# bowler_wicket       278205
# batting_partners    278205
# next_batter          13321
# striker_out         278205
# Length: 64, dtype: int64
# top 10 rows
#
#    Unnamed: 0  match_id        date match_type             event_name  \
# 0      131970    335982  2008-04-18        T20  Indian Premier League
# 1      131971    335982  2008-04-18        T20  Indian Premier League
# 2      131972    335982  2008-04-18        T20  Indian Premier League
# 3      131973    335982  2008-04-18        T20  Indian Premier League
# 4      131974    335982  2008-04-18        T20  Indian Premier League
# 5      131975    335982  2008-04-18        T20  Indian Premier League
# 6      131976    335982  2008-04-18        T20  Indian Premier League
# 7      131977    335982  2008-04-18        T20  Indian Premier League
# 8      131978    335982  2008-04-18        T20  Indian Premier League
# 9      131979    335982  2008-04-18        T20  Indian Premier League
#
#    innings           batting_team                 bowling_team  over  ball  \
# 0        1  Kolkata Knight Riders  Royal Challengers Bangalore     0     1
# 1        1  Kolkata Knight Riders  Royal Challengers Bangalore     0     2
# 2        1  Kolkata Knight Riders  Royal Challengers Bangalore     0     3
# 3        1  Kolkata Knight Riders  Royal Challengers Bangalore     0     3
# 4        1  Kolkata Knight Riders  Royal Challengers Bangalore     0     4
# 5        1  Kolkata Knight Riders  Royal Challengers Bangalore     0     5
# 6        1  Kolkata Knight Riders  Royal Challengers Bangalore     0     6
# 7        1  Kolkata Knight Riders  Royal Challengers Bangalore     1     1
# 8        1  Kolkata Knight Riders  Royal Challengers Bangalore     1     2
# 9        1  Kolkata Knight Riders  Royal Challengers Bangalore     1     3
#
#    ...  team_runs team_balls  team_wicket  new_batter  batter_runs  \
# 0  ...          1          1            0         NaN            0
# 1  ...          1          2            0         NaN            0
# 2  ...          2          2            0         NaN            0
# 3  ...          2          3            0         NaN            0
# 4  ...          2          4            0         NaN            0
# 5  ...          2          5            0         NaN            0
# 6  ...          3          6            0         NaN            0
# 7  ...          3          7            0         NaN            0
# 8  ...          7          8            0         NaN            4
# 9  ...         11          9            0         NaN            8
#
#   batter_balls  bowler_wicket               batting_partners  next_batter  \
# 0            1              0  ('BB McCullum', 'SC Ganguly')          NaN
# 1            1              0  ('BB McCullum', 'SC Ganguly')          NaN
# 2            1              0  ('BB McCullum', 'SC Ganguly')          NaN
# 3            2              0  ('BB McCullum', 'SC Ganguly')          NaN
# 4            3              0  ('BB McCullum', 'SC Ganguly')          NaN
# 5            4              0  ('BB McCullum', 'SC Ganguly')          NaN
# 6            5              0  ('BB McCullum', 'SC Ganguly')          NaN
# 7            6              0  ('BB McCullum', 'SC Ganguly')          NaN
# 8            7              0  ('BB McCullum', 'SC Ganguly')          NaN
# 9            8              0  ('BB McCullum', 'SC Ganguly')          NaN
#
#    striker_out
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
# 6        False
# 7        False
# 8        False
# 9        False
#
# [10 rows x 64 columns]
# bottom 10 rows
#
#         Unnamed: 0  match_id        date match_type             event_name  \
# 278195      277946   1473511  2025-06-03        T20  Indian Premier League
# 278196      277947   1473511  2025-06-03        T20  Indian Premier League
# 278197      277948   1473511  2025-06-03        T20  Indian Premier League
# 278198      277949   1473511  2025-06-03        T20  Indian Premier League
# 278199      277950   1473511  2025-06-03        T20  Indian Premier League
# 278200      277951   1473511  2025-06-03        T20  Indian Premier League
# 278201      277952   1473511  2025-06-03        T20  Indian Premier League
# 278202      277953   1473511  2025-06-03        T20  Indian Premier League
# 278203      277954   1473511  2025-06-03        T20  Indian Premier League
# 278204      277955   1473511  2025-06-03        T20  Indian Premier League
#
#         innings  batting_team                 bowling_team  over  ball  ...  \
# 278195        2  Punjab Kings  Royal Challengers Bengaluru    18     3  ...
# 278196        2  Punjab Kings  Royal Challengers Bengaluru    18     4  ...
# 278197        2  Punjab Kings  Royal Challengers Bengaluru    18     5  ...
# 278198        2  Punjab Kings  Royal Challengers Bengaluru    18     6  ...
# 278199        2  Punjab Kings  Royal Challengers Bengaluru    19     1  ...
# 278200        2  Punjab Kings  Royal Challengers Bengaluru    19     2  ...
# 278201        2  Punjab Kings  Royal Challengers Bengaluru    19     3  ...
# 278202        2  Punjab Kings  Royal Challengers Bengaluru    19     4  ...
# 278203        2  Punjab Kings  Royal Challengers Bengaluru    19     5  ...
# 278204        2  Punjab Kings  Royal Challengers Bengaluru    19     6  ...
#
#         team_runs team_balls  team_wicket  new_batter  batter_runs  \
# 278195        155        111            7         NaN           32
# 278196        159        112            7         NaN           36
# 278197        161        113            7         NaN           38
# 278198        162        114            7         NaN           39
# 278199        162        115            7         NaN           39
# 278200        162        116            7         NaN           39
# 278201        168        117            7         NaN           45
# 278202        172        118            7         NaN           49
# 278203        178        119            7         NaN           55
# 278204        184        120            7         NaN           61
#
#        batter_balls  bowler_wicket                   batting_partners  \
# 278195           21              0  ('KA Jamieson', 'Shashank Singh')
# 278196           22              0  ('KA Jamieson', 'Shashank Singh')
# 278197           23              0  ('KA Jamieson', 'Shashank Singh')
# 278198           24              0  ('KA Jamieson', 'Shashank Singh')
# 278199           25              0  ('KA Jamieson', 'Shashank Singh')
# 278200           26              0  ('KA Jamieson', 'Shashank Singh')
# 278201           27              0  ('KA Jamieson', 'Shashank Singh')
# 278202           28              0  ('KA Jamieson', 'Shashank Singh')
# 278203           29              0  ('KA Jamieson', 'Shashank Singh')
# 278204           30              0  ('KA Jamieson', 'Shashank Singh')
#
#         next_batter  striker_out
# 278195          NaN        False
# 278196          NaN        False
# 278197          NaN        False
# 278198          NaN        False
# 278199          NaN        False
# 278200          NaN        False
# 278201          NaN        False
# 278202          NaN        False
# 278203          NaN        False
# 278204          NaN        False
#
# [10 rows x 64 columns]

# %%
ipl.isnull().sum().sort_values(ascending=False).head(20)
# Out:
# team_reviewed       277333
# umpire              277333
# review_batter       277333
# review_decision     277333
# method              274315
# superover_winner    274309
# result_type         273503
# fielders            268192
# new_batter          264884
# next_batter         264884
# player_out          264382
# wicket_kind         264382
# extra_type          263072
# runs_target         144302
# win_outcome           4702
# month                    0
# day                      0
# city                     0
# year                     0
# season                   0
# dtype: int64

# %%
ipl.drop(columns=['team_reviewed', 'umpire', 'match_type', 'event_name','gender', 'team_type', 'balls_per_over', 'overs', 'event_match_no', 'match_number'], inplace=True)

# %%
print(ipl.shape)
print(ipl.columns)
# Out:
# (278205, 54)
# Index(['Unnamed: 0', 'match_id', 'date', 'innings', 'batting_team',
#        'bowling_team', 'over', 'ball', 'ball_no', 'batter', 'bat_pos',
#        'runs_batter', 'balls_faced', 'bowler', 'valid_ball', 'runs_extras',
#        'runs_total', 'runs_bowler', 'runs_not_boundary', 'extra_type',
#        'non_striker', 'non_striker_pos', 'wicket_kind', 'player_out',
#        'fielders', 'runs_target', 'review_batter', 'review_decision',
#        'umpires_call', 'player_of_match', 'match_won_by', 'win_outcome',
#        'toss_winner', 'toss_decision', 'venue', 'city', 'day', 'month', 'year',
#        'season', 'superover_winner', 'result_type', 'method', 'stage',
#        'team_runs', 'team_balls', 'team_wicket', 'new_batter', 'batter_runs',
#        'batter_balls', 'bowler_wicket', 'batting_partners', 'next_batter',
#        'striker_out'],
#       dtype='object')

# %%
ipl.isnull().sum().sort_values(ascending=False).head(20)
# Out:
# review_decision     277333
# review_batter       277333
# method              274315
# superover_winner    274309
# result_type         273503
# fielders            268192
# next_batter         264884
# new_batter          264884
# player_out          264382
# wicket_kind         264382
# extra_type          263072
# runs_target         144302
# win_outcome           4702
# stage                    0
# team_wicket              0
# toss_winner              0
# toss_decision            0
# batting_partners         0
# bowler_wicket            0
# batter_balls             0
# dtype: int64

# %%
#dealing with missing values and cleaning data
ipl['wicket_kind'] = ipl['wicket_kind'].fillna("None")
ipl['player_out'] = ipl['player_out'].fillna("None")
ipl['extra_type'] = ipl['extra_type'].fillna("None")

rare_cols = ['review_batter', 'review_decision', 'method', 'superover_winner']
for col in rare_cols:
    if col in ipl.columns:
        ipl[col] = ipl[col].fillna("Not Applicable")

ipl['runs_target'] = ipl['runs_target'].fillna(0)
ipl['win_outcome'] = ipl['win_outcome'].fillna("Unknown")

other_cols = ['fielders', 'new_batter', 'next_batter']
for col in other_cols:
    if col in ipl.columns:
        ipl[col] = ipl[col].fillna("None")

ipl['runs_total'] = pd.to_numeric(ipl['runs_total'], errors='coerce')
ipl['over'] = pd.to_numeric(ipl['over'], errors='coerce')


# FINAL CHECK
print("Remaining missing values:\n")
print(ipl.isnull().sum().sort_values(ascending=False).head(10))
# Out:
# Remaining missing values:
#
# result_type         273503
# superover_winner         0
# player_of_match          0
# match_won_by             0
# win_outcome              0
# toss_winner              0
# toss_decision            0
# venue                    0
# city                     0
# day                      0
# dtype: int64

# %%
ipl['result_type'] = ipl.groupby('match_id')['result_type'].ffill()
ipl['result_type'] = ipl['result_type'].fillna("Unknown")

# FINAL CHECK
print("Remaining missing values:\n")
print(ipl.isnull().sum().sort_values(ascending=False).head(10))
# Out:
# Remaining missing values:
#
# Unnamed: 0          0
# superover_winner    0
# player_of_match     0
# match_won_by        0
# win_outcome         0
# toss_winner         0
# toss_decision       0
# venue               0
# city                0
# day                 0
# dtype: int64

# %%
#Top teams acc. to scoring rate
print("team's scoring rate (runs/ball):\n")
team_sr = ipl.groupby('batting_team')['runs_total'].sum() / ipl.groupby('batting_team').size()
team_sr = team_sr.sort_values(ascending=False)
print(team_sr.head(10))
# Out:
# team's scoring rate (runs/ball):
#
# batting_team
# Royal Challengers Bengaluru    1.581138
# Gujarat Titans                 1.452599
# Punjab Kings                   1.443655
# Lucknow Super Giants           1.433651
# Delhi Capitals                 1.379310
# Gujarat Lions                  1.363432
# Mumbai Indians                 1.353059
# Chennai Super Kings            1.351209
# Sunrisers Hyderabad            1.347581
# Rajasthan Royals               1.338049
# dtype: float64

# %%
print("Total Wins by Teams:\n")
wins = ipl[['batting_team', 'win_outcome']].drop_duplicates()

wins_count = wins[wins['win_outcome'] != "Unknown"]['batting_team'].value_counts()

print(wins_count.head(10))
# Out:
# Total Wins by Teams:
#
# batting_team
# Mumbai Indians                 75
# Royal Challengers Bangalore    72
# Rajasthan Royals               71
# Kolkata Knight Riders          70
# Chennai Super Kings            68
# Sunrisers Hyderabad            59
# Kings XI Punjab                58
# Delhi Daredevils               50
# Delhi Capitals                 48
# Deccan Chargers                35
# Name: count, dtype: int64

# %%
def phase(over):
    if over <= 6:
        return "Powerplay Overs"
    elif over <= 15:
        return "Middle Overs"
    else:
        return "Death Overs"

ipl['phase'] = ipl['over'].apply(phase)

phase_runs = ipl.groupby('phase')['runs_total'].mean()

print(phase_runs)
# Out:
# phase
# Death Overs        1.626365
# Middle Overs       1.308156
# Powerplay Overs    1.254867
# Name: runs_total, dtype: float64

# %%
phase_wickets = ipl.groupby('phase')['team_wicket'].sum()

print(phase_wickets)
# Out:
# phase
# Death Overs        247699
# Middle Overs       352139
# Powerplay Overs     83704
# Name: team_wicket, dtype: int64

# %%
wicket_rate = ipl.groupby('phase')['team_wicket'].sum() / ipl.groupby('phase').size()

print(wicket_rate)
# Out:
# phase
# Death Overs        4.998870
# Middle Overs       2.774015
# Powerplay Overs    0.822951
# dtype: float64

# %%
cleaned_data_sample= ipl.sample(3000)
cleaned_data_sample.to_csv("cleaned_data_sample.csv",index=False)

# %%
print(cleaned_data_sample.shape)
# Out:
# (3000, 55)
