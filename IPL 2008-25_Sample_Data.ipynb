# %%
import numpy as np
import pandas as pd

# %%
ipl=pd.read_csv(r"C:\Users\Vijay\Data Analytics\IPL_2008-25_Analysis\IPL.csv", low_memory=False)

# %%
ipl_sample = ipl.sample(3000)
ipl_sample.to_csv("sample_data.csv", index=False)

# %%
print(ipl_sample.shape)
# Out:
# (3000, 64)
